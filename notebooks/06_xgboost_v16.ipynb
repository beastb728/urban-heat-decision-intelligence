# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from xgboost import XGBRegressor

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %%
X_train = pd.read_csv("../data/processed/X_train_v16.csv")
X_test = pd.read_csv("../data/processed/X_test_v16.csv")

y_train = pd.read_csv("../data/processed/y_train_v16.csv").squeeze()
y_test = pd.read_csv("../data/processed/y_test_v16.csv").squeeze()

# %%
print(X_train.shape)
print(X_test.shape)

print(y_train.shape)
print(y_test.shape)
# Out:
# (25545, 5)
# (6387, 5)
# (25545,)
# (6387,)

# %%
xgb = XGBRegressor(
    n_estimators=200,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1
)

# %%
xgb.fit(
    X_train,
    y_train
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=-1, num_parallel_tree=None, ...)

# %%
y_pred = xgb.predict(
    X_test
)

# %%
rmse = np.sqrt(
    mean_squared_error(
        y_test,
        y_pred
    )
)

mae = mean_absolute_error(
    y_test,
    y_pred
)

r2 = r2_score(
    y_test,
    y_pred
)

# %%
print("XGBoost v16 Results")

print(f"RMSE: {rmse:.3f} °C")
print(f"MAE : {mae:.3f} °C")
print(f"R²  : {r2:.3f}")
# Out:
# XGBoost v16 Results
# RMSE: 2.591 °C
# MAE : 1.656 °C
# R²  : 0.710

# %%
rf_rmse = 2.611
rf_mae = 1.655
rf_r2 = 0.705

print("\nCompared to RF v16")

print(
    f"RMSE difference: {rf_rmse - rmse:.3f}"
)

print(
    f"MAE difference: {rf_mae - mae:.3f}"
)

print(
    f"R² difference: {r2 - rf_r2:.3f}"
)
# Out:
# Compared to RF v16
# RMSE difference: 0.020
# MAE difference: -0.001
# R² difference: 0.005

# %%
importance = pd.Series(
    xgb.feature_importances_,
    index=X_train.columns
).sort_values(
    ascending=False
)

print(importance)
# Out:
# mean_ndbi          0.411043
# mean_albedo        0.363561
# mean_ndvi          0.087250
# mean_ndwi          0.080819
# mean_emissivity    0.057327
# dtype: float32

# %%
importance.plot(
    kind="bar"
)

plt.title(
    "XGBoost Feature Importance"
)

plt.ylabel(
    "Importance"
)

plt.show()

# %%
plt.figure(figsize=(7, 7))

plt.scatter(
    y_test,
    y_pred,
    alpha=0.3
)

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    'r--'
)

plt.xlabel(
    "Observed LST"
)

plt.ylabel(
    "Predicted LST"
)

plt.title(
    "Observed vs Predicted LST"
)

plt.show()

# %%
residuals = y_test - y_pred

plt.figure(figsize=(7, 5))

plt.hist(
    residuals,
    bins=50
)

plt.xlabel(
    "Residual (°C)"
)

plt.ylabel(
    "Frequency"
)

plt.title(
    "Residual Distribution"
)

plt.show()
