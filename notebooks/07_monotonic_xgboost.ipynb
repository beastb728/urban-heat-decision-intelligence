# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from xgboost import XGBRegressor

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %%
X_train = pd.read_csv("../data/processed/X_train_v16.csv")
X_test = pd.read_csv("../data/processed/X_test_v16.csv")

y_train = pd.read_csv("../data/processed/y_train_v16.csv").squeeze()
y_test = pd.read_csv("../data/processed/y_test_v16.csv").squeeze()

# %%
print(X_train.columns.tolist())
# Out:
# ['mean_ndvi', 'mean_ndbi', 'mean_ndwi', 'mean_emissivity', 'mean_albedo']

# %%
constraints = (
    -1,   # NDVI
     1,   # NDBI
    -1,   # NDWI
     0,   # Emissivity
    -1    # Albedo
)

# %%
mono_xgb = XGBRegressor(
    n_estimators=200,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    monotone_constraints=constraints,
    random_state=42,
    n_jobs=-1
)

# %%
mono_xgb.fit(
    X_train,
    y_train
)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=(-1, 1, -1, 0, -1), multi_strategy=None,
#              n_estimators=200, n_jobs=-1, num_parallel_tree=None, ...)

# %%
y_pred = mono_xgb.predict(
    X_test
)

# %%
rmse = np.sqrt(
    mean_squared_error(
        y_test,
        y_pred
    )
)

mae = mean_absolute_error(
    y_test,
    y_pred
)

r2 = r2_score(
    y_test,
    y_pred
)

# %%
print("Monotonic XGBoost Results")

print(f"RMSE: {rmse:.3f} °C")
print(f"MAE : {mae:.3f} °C")
print(f"R²  : {r2:.3f}")
# Out:
# Monotonic XGBoost Results
# RMSE: 2.721 °C
# MAE : 1.731 °C
# R²  : 0.680

# %%
xgb_rmse = 2.591
xgb_mae = 1.656
xgb_r2 = 0.710

print("\nCompared to standard XGBoost")

print(
    f"RMSE difference: {xgb_rmse - rmse:.3f}"
)

print(
    f"MAE difference: {xgb_mae - mae:.3f}"
)

print(
    f"R² difference: {r2 - xgb_r2:.3f}"
)
# Out:
# Compared to standard XGBoost
# RMSE difference: -0.130
# MAE difference: -0.075
# R² difference: -0.030

# %%
importance = pd.Series(
    mono_xgb.feature_importances_,
    index=X_train.columns
).sort_values(
    ascending=False
)

print(importance)
# Out:
# mean_ndbi          0.476198
# mean_albedo        0.352297
# mean_ndvi          0.068572
# mean_ndwi          0.068431
# mean_emissivity    0.034503
# dtype: float32

# %%
importance.plot(
    kind="bar"
)

plt.title(
    "Monotonic XGBoost Feature Importance"
)

plt.ylabel(
    "Importance"
)

plt.show()
