# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %%
X_train = pd.read_csv("../data/processed/X_train_v16.csv")
X_test = pd.read_csv("../data/processed/X_test_v16.csv")

y_train = pd.read_csv("../data/processed/y_train_v16.csv").squeeze()
y_test = pd.read_csv("../data/processed/y_test_v16.csv").squeeze()

# %%
print(X_train.shape)
print(X_test.shape)

print(y_train.shape)
print(y_test.shape)
# Out:
# (25545, 5)
# (6387, 5)
# (25545,)
# (6387,)

# %%
rf = RandomForestRegressor(
    n_estimators=100,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
y_pred = rf.predict(X_test)

# %%
rmse = np.sqrt(
    mean_squared_error(y_test, y_pred)
)

mae = mean_absolute_error(
    y_test,
    y_pred
)

r2 = r2_score(
    y_test,
    y_pred
)

# %%
print("Random Forest v16 Results")

print(f"RMSE: {rmse:.3f} °C")
print(f"MAE : {mae:.3f} °C")
print(f"R²  : {r2:.3f}")
# Out:
# Random Forest v16 Results
# RMSE: 2.611 °C
# MAE : 1.655 °C
# R²  : 0.705

# %%
baseline_rmse = 3.74
baseline_mae = 2.31
baseline_r2 = 0.397

print("\nImprovement over baseline")

print(
    f"RMSE change: {baseline_rmse - rmse:.3f}"
)

print(
    f"MAE change: {baseline_mae - mae:.3f}"
)

print(
    f"R² change: {r2 - baseline_r2:.3f}"
)
# Out:
# Improvement over baseline
# RMSE change: 1.129
# MAE change: 0.655
# R² change: 0.308

# %%
importance = pd.Series(
    rf.feature_importances_,
    index=X_train.columns
).sort_values(ascending=False)

importance
# Out:
# mean_ndbi          0.446069
# mean_albedo        0.341313
# mean_ndwi          0.105684
# mean_ndvi          0.058588
# mean_emissivity    0.048346
# dtype: float64

# %%
importance.plot(kind="bar")

plt.title(
    "Random Forest Feature Importance"
)

plt.ylabel("Importance")

plt.show()

# %%
plt.figure(figsize=(7, 7))

plt.scatter(
    y_test,
    y_pred,
    alpha=0.3
)

plt.xlabel("Observed LST")

plt.ylabel("Predicted LST")

plt.title(
    "Observed vs Predicted LST"
)

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    'r--'
)

plt.show()

# %%
residuals = y_test - y_pred

plt.figure(figsize=(7, 5))

plt.hist(
    residuals,
    bins=50
)

plt.title(
    "Residual Distribution"
)

plt.xlabel("Prediction Error (°C)")

plt.ylabel("Frequency")

plt.show()
